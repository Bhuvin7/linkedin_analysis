# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\bhuve\Downloads\final_data.csv")
df
# Out:
#     Company_Name    Class                                        Designation  \
# 0          Wipro  Class 3                                    Project Manager
# 1          Wipro  Class 3                                    Project Manager
# 2          Wipro  Class 3                                    Project Manager
# 3          Wipro  Class 3                                      Administrator
# 4          Wipro  Class 3                                    Project Manager
# ..           ...      ...                                                ...
# 806      Infosys  Class 3                    Java Developer (5-8 yrs) Indore
# 807      Infosys  Class 3  Technology Analyst - NodeJs (3-5 years) - Bhub...
# 808      Genpact  Class 1                             Hiring for OTC- JAIPUR
# 809      Genpact  Class 1                                      C++ Developer
# 810      Genpact  Class 1                             Hiring for RTR- Jaipur
#
# ...

# %%
df.columns
# Out:
# Index(['Company_Name', 'Class', 'Designation', 'Location', 'Total_applicants',
#        'LinkedIn_Followers', 'Level', 'Involvement', 'Employee_count',
#        'Industry', 'PYTHON', 'C++', 'JAVA', 'HADOOP', 'SCALA', 'FLASK',
#        'PANDAS', 'SPARK', 'NUMPY', 'PHP', 'SQL', 'MYSQL', 'CSS', 'MONGODB',
#        'NLTK', 'TENSORFLOW', 'LINUX', 'RUBY', 'JAVASCRIPT', 'DJANGO', 'REACT',
#        'REACTJS', 'AI', 'UI', 'TABLEAU', 'NODEJS', 'EXCEL', 'POWER BI',
#        'SELENIUM', 'HTML', 'ML'],
#       dtype='object')

# %%
df
# Out:
#     Company_Name    Class                                        Designation  \
# 0          Wipro  Class 3                                    Project Manager
# 1          Wipro  Class 3                                    Project Manager
# 2          Wipro  Class 3                                    Project Manager
# 3          Wipro  Class 3                                      Administrator
# 4          Wipro  Class 3                                    Project Manager
# ..           ...      ...                                                ...
# 806      Infosys  Class 3                    Java Developer (5-8 yrs) Indore
# 807      Infosys  Class 3  Technology Analyst - NodeJs (3-5 years) - Bhub...
# 808      Genpact  Class 1                             Hiring for OTC- JAIPUR
# 809      Genpact  Class 1                                      C++ Developer
# 810      Genpact  Class 1                             Hiring for RTR- Jaipur
#
# ...

# %%
df = df.drop(columns=['Class'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 df = df.drop(columns=['Class'])
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)   5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)   5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
#    5588         errors=errors,
#    5589     )
#
# ...

# %%
df
# Out:
#     Company_Name                                        Designation  \
# 0          Wipro                                    Project Manager
# 1          Wipro                                    Project Manager
# 2          Wipro                                    Project Manager
# 3          Wipro                                      Administrator
# 4          Wipro                                    Project Manager
# ..           ...                                                ...
# 806      Infosys                    Java Developer (5-8 yrs) Indore
# 807      Infosys  Technology Analyst - NodeJs (3-5 years) - Bhub...
# 808      Genpact                             Hiring for OTC- JAIPUR
# 809      Genpact                                      C++ Developer
# 810      Genpact                             Hiring for RTR- Jaipur
#
#             Location  Total_applicants  LinkedIn_Followers       Level  \
# 0        Maharashtra                 0             6737300  Full-time
# ...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of     Company_Name                                        Designation  \
# 0          Wipro                                    Project Manager
# 1          Wipro                                    Project Manager
# 2          Wipro                                    Project Manager
# 3          Wipro                                      Administrator
# 4          Wipro                                    Project Manager
# ..           ...                                                ...
# 806      Infosys                    Java Developer (5-8 yrs) Indore
# 807      Infosys  Technology Analyst - NodeJs (3-5 years) - Bhub...
# 808      Genpact                             Hiring for OTC- JAIPUR
# 809      Genpact                                      C++ Developer
# 810      Genpact                             Hiring for RTR- Jaipur
#
#             Location  Total_applicants  LinkedIn_Followers       Level  \
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of     Company_Name                                        Designation  \
# 0          Wipro                                    Project Manager
# 1          Wipro                                    Project Manager
# 2          Wipro                                    Project Manager
# 3          Wipro                                      Administrator
# 4          Wipro                                    Project Manager
# ..           ...                                                ...
# 806      Infosys                    Java Developer (5-8 yrs) Indore
# 807      Infosys  Technology Analyst - NodeJs (3-5 years) - Bhub...
# 808      Genpact                             Hiring for OTC- JAIPUR
# 809      Genpact                                      C++ Developer
# 810      Genpact                             Hiring for RTR- Jaipur
#
#             Location  Total_applicants  LinkedIn_Followers       Level  \
# ...

# %%
df.isnull
# Out:
# <bound method DataFrame.isnull of     Company_Name                                        Designation  \
# 0          Wipro                                    Project Manager
# 1          Wipro                                    Project Manager
# 2          Wipro                                    Project Manager
# 3          Wipro                                      Administrator
# 4          Wipro                                    Project Manager
# ..           ...                                                ...
# 806      Infosys                    Java Developer (5-8 yrs) Indore
# 807      Infosys  Technology Analyst - NodeJs (3-5 years) - Bhub...
# 808      Genpact                             Hiring for OTC- JAIPUR
# 809      Genpact                                      C++ Developer
# 810      Genpact                             Hiring for RTR- Jaipur
#
#             Location  Total_applicants  LinkedIn_Followers       Level  \
# ...

# %%
df.isna().sum()
# Out:
# Company_Name          0
# Designation           0
# Location              0
# Total_applicants      0
# LinkedIn_Followers    0
# Level                 0
# Involvement           0
# Employee_count        0
# Industry              0
# PYTHON                0
# C++                   0
# JAVA                  0
# HADOOP                0
# SCALA                 0
# FLASK                 0
# PANDAS                0
# SPARK                 0
# NUMPY                 0
# PHP                   0
# SQL                   0
# MYSQL                 0
# CSS                   0
# MONGODB               0
# NLTK                  0
# TENSORFLOW            0
# LINUX                 0
# RUBY                  0
# JAVASCRIPT            0
# DJANGO                0
# REACT                 0
# REACTJS               0
# AI                    0
# UI                    0
# TABLEAU               0
# NODEJS                0
# EXCEL                 0
# POWER BI              0
# SELENIUM              0
# ...

# %%
df.drop_duplicates
# Out:
# <bound method DataFrame.drop_duplicates of     Company_Name                                        Designation  \
# 0          Wipro                                    Project Manager
# 1          Wipro                                    Project Manager
# 2          Wipro                                    Project Manager
# 3          Wipro                                      Administrator
# 4          Wipro                                    Project Manager
# ..           ...                                                ...
# 806      Infosys                    Java Developer (5-8 yrs) Indore
# 807      Infosys  Technology Analyst - NodeJs (3-5 years) - Bhub...
# 808      Genpact                             Hiring for OTC- JAIPUR
# 809      Genpact                                      C++ Developer
# 810      Genpact                             Hiring for RTR- Jaipur
#
#             Location  Total_applicants  LinkedIn_Followers       Level  \
# ...
